# %%
from flask import Flask, jsonify
from flask_sqlalchemy import SQLAlchemy
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import Column, Integer, String, Float
Base = automap_base()

# %%
engine = create_engine('postgresql://postgres:password@localhost/trade')
#Base.metadata.create_all(engine)
session = Session(bind=engine)
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\ext\declarative\clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.export_dollars, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\ext\declarative\clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.country_growth, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\ext\declarative\clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.import_dollars, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# ...

# %%
# class Export_data(Base):
#     __tablename__ = 'export_dollars'
#     reporter_name = Column(String)
#     _year = Column(String)
#     partner_name = Column(String)
#     trade_flow = Column(String)
#     product_group = Column(String)
#     _indicator = Column(String)
#     total = Column(Float)
#     id = Column(Integer, primary_key=True)

# %%
trade_t = Base.classes.trade_table

# %%
session = Session(engine)

# %%
first_row = session.query(trade_t).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1eb4a04c448>,
#  'trade_flow': 'Import',
#  'reporter_name': 'Australia',
#  'trade_indicator': 'Import (US$ Thousand)',
#  'total_dollars': 200617274.5,
#  'id': 1,
#  '_year': '2008',
#  'product_group': '  All Products',
#  'total_perc': 100.0}

# %%
trade_query = session.query(trade_t.reporter_name, trade_t._year, trade_t.trade_flow, trade_t.product_group, trade_t.trade_indicator, trade_t.total_dollars, trade_t.total_perc).all()

# %%
all_results = []
for trade_t.reporter_name, trade_t._year, trade_t.trade_flow, trade_t.product_group, trade_t.indicator, trade_t.total_dollars, trade_t.total_perc in trade_query:
    results_dict = {}
    results_dict["reporter_name"] = trade_t.reporter_name
    results_dict["year"] = trade_t._year
    results_dict["trade_flow"] = trade_t.trade_flow
    results_dict["product_group"] = trade_t.product_group
    results_dict["indicator"] = trade_t.trade_indicator
    results_dict["total_dollars"] = trade_t.total_dollars
    results_dict["total_percent"] = trade_t.total_perc
    all_results.append(results_dict)

# %%
all_results = []
for CouG.indicator_type, CouG.country, CouG.y_2017, CouG.y_2018 in coug_query:
        results_dict = {}
        results_dict["indicator"] = CouG.indicator_type
        results_dict["country"] = CouG.country
        results_dict["2017"] = CouG.y_2017
        results_dict["2018"] =  CouG.y_2018
        all_results.append(results_dict)

# %%
print(all_results)
# Out:
# [{'reporter_name': 'Australia', 'year': '2008', 'trade_flow': 'Import', 'product_group': '  All Products', 'indicator': <sqlalchemy.orm.attributes.InstrumentedAttribute object at 0x000001EB4A00CB28>, 'total_dollars': 200617274.5, 'total_percent': 100.0}, {'reporter_name': 'Australia', 'year': '2008', 'trade_flow': 'Import', 'product_group': ' Capital goods', 'indicator': <sqlalchemy.orm.attributes.InstrumentedAttribute object at 0x000001EB4A00CB28>, 'total_dollars': 61880820.31, 'total_percent': 5.7558}, {'reporter_name': 'Australia', 'year': '2008', 'trade_flow': 'Import', 'product_group': ' Consumer goods', 'indicator': <sqlalchemy.orm.attributes.InstrumentedAttribute object at 0x000001EB4A00CB28>, 'total_dollars': 79244348.65, 'total_percent': 15.1473}, {'reporter_name': 'Australia', 'year': '2008', 'trade_flow': 'Import', 'product_group': ' Intermediate goods', 'indicator': <sqlalchemy.orm.attributes.InstrumentedAttribute object at 0x000001EB4A00CB28>, 'total_dollars': 37420942.6
# ...

# %%
session.close()

# %%
# all_results = []
# for ExpD.reporter_name, ExpD.year, ExpD._indicator, ExpD.total in arg_query_year:
#         results_dict = {}
#         results_dict["reporter_name"] = ExpD.reporter_name
#         results_dict["year"] = ExpD.year
#         results_dict["indicator"] = ExpD._indicator
#         results_dict["total"] = ExpD.total
#         all_results.append(results_dict)

# %%
print(all_results)
# Out:
# []

# %%
ImpDol = Base.classes.import_dollars
session = Session(engine)

imp_query = session.query(ImpDol.reporter_name, ImpDol.partner_name, ImpDol.product_group, ImpDol._indicator, ImpDol.y_2013, ImpDol.y_2014,ImpDol.y_2015,ImpDol.y_2016,ImpDol.y_2017,ImpDol.y_2018).all()

all_results = []
for ImpDol.reporter_name, ImpDol.partner_name, ImpDol.product_group, ImpDol._indicator, ImpDol.y_2013, ImpDol.y_2014,ImpDol.y_2015,ImpDol.y_2016,ImpDol.y_2017,ImpDol.y_2018 in imp_query:
    results_dict = {}
    results_dict["reporter_name"] = ImpDol.reporter_name
    results_dict["partner_name"] = ImpDol.partner_name
    results_dict["product_group"] = ImpDol.product_group
    results_dict["_indicator"] =  ImpDol._indicator
    results_dict["2013"] =  ImpDol.y_2013
    results_dict["2014"] =  ImpDol.y_2014
    results_dict["2015"] =  ImpDol.y_2015
    results_dict["2016"] =  ImpDol.y_2016
    results_dict["2017"] =  ImpDol.y_2017
    results_dict["2018"] =  ImpDol.y_2018
    all_results.append(results_dict)

print(all_results)
# Out:
# [{'reporter_name': 'Argentina', 'partner_name': ' World', 'product_group': '  All Products', '_indicator': 'Import (US$ Thousand)', '2013': 74441745.28, '2014': 65735987.76, '2015': 60202843.5, '2016': 55910810.44, '2017': 66899299.59, '2018': 65440966.17}, {'reporter_name': 'Argentina', 'partner_name': ' World', 'product_group': ' Capital goods', '_indicator': 'Macro Import (US$ Thousand)', '2013': 26852442.34, '2014': 24248530.96, '2015': 23989205.07, '2016': 22583039.85, '2017': 27109184.06, '2018': 23645136.5}, {'reporter_name': 'Argentina', 'partner_name': ' World', 'product_group': ' Consumer goods', '_indicator': 'Macro Import (US$ Thousand)', '2013': 28752007.78, '2014': 23006335.35, '2015': 18865800.21, '2016': 18178529.31, '2017': 22101040.68, '2018': 21978986.54}, {'reporter_name': 'Argentina', 'partner_name': ' World', 'product_group': ' Intermediate goods', '_indicator': 'Macro Import (US$ Thousand)', '2013': 15761030.97, '2014': 15208591.16, '2015': 14655195.53, '2016':
# ...
